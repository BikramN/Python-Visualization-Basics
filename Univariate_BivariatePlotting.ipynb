# %%
import pandas as pd
import matplotlib.pyplot as plt
df_shopping = pd.read_csv("D:\DATASETS\Shopping_CustomerData.csv",sep = ",",usecols = [0,1,2,3,4,5,6,7])

# %%
df_shopping.head()
# Out:
#    CustomerID CustomerGender  CustomerAge CustomerCity  AnnualIncome  \
# 0        1001           Male           49    Bengaluru  527547.58850
# 1        1002           Male           59    Bengaluru  207143.19760
# 2        1003         Female           54        Delhi  164423.84570
# 3        1004         Female           42    Bengaluru   56220.36443
# 4        1005         Female           30    Bengaluru  256194.36190
#
#    CreditScore  SpendingScore  CustomerCityID
# 0          653             78               1
# 1          630             63               1
# 2          555             69               4
# 3          699             30               1
# 4          793              6               1

# %%
df_shopping.CustomerGender.value_counts().plot.bar()

# %%
df_shopping.SpendingScore.value_counts().sort_index().plot.line()

# %%
df_shopping.CreditScore.value_counts().sort_index().plot.area()

# %%
df_shopping.head(20).CustomerCityID.plot.hist()

# %%
df_shopping.head(20).plot.scatter(x="AnnualIncome",y="SpendingScore")

# %%
df_shopping[df_shopping.SpendingScore>50].plot.hexbin(x="SpendingScore",y="CreditScore")

# %%
shopindex = pd.read_csv("D:\DATASETS\Shopping_ShoppingIndexData.csv",sep=",",index_col="ShoppingIndex")

# %%
shopindex.head()
# Out:
#                Bengaluru  Chennai  Kolkata  Delhi  Mumbai
# ShoppingIndex
# 92                   180      159      204    134     339
# 90                   121      336      419    419     346
# 88                   153      242      399    378     107
# 87                   163      156      186    364     419
# 85                   404      115      133    426     353

# %%
shopindex.plot.bar()

# %%
shopindex.plot.bar(stacked = True)

# %%
shopindex.plot.area()
